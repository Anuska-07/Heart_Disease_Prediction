# %% [markdown]
# ---  Cleaning and Analyzing the Dataset  ---

# %% [markdown]
# -Importing the required libraries.

# %% [markdown]
# Here, pandas is used to read dataset, numpy works with numbers, matplotlib creates graph and seaborn makes preetier graphs

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# -Loading Dataset.

# %%
data=pd.read_csv("dataset.csv")

# %% [markdown]
# -Displaying the first five rows.

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# -Displaying the last five rows.

# %%
data.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %% [markdown]
# -Displaying the data of random 5 people.

# %%
data.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 262   53    1   0       123   282    0        1       95      1      2.0
# 27    51    1   2       110   175    0        1      123      0      0.6
# 274   47    1   0       110   275    0        0      118      1      1.0
# 123   54    0   2       108   267    0        0      167      0      0.0
# 187   54    1   0       124   266    0        0      109      1      2.2
#
#      slope  ca  thal  target
# 262      1   2     3       0
# 27       2   0     2       1
# 274      1   1     2       0
# 123      2   0     2       1
# 187      1   1     3       0

# %% [markdown]
# -No. of rows and columns

# %%
data.shape
# Out:
# (303, 14)

# %% [markdown]
# The given data set has 303 rows and 14 column.

# %% [markdown]
# -Displaying names of columns.

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='str')

# %% [markdown]
# cp: Chest Pain Type
# trestbps: Resting Blood Pressure
# chol: Cholesterol Level
# fbs: Fasting Blood Sugar
# restecg: Electrocardiogram result
# thalach: Max. heart rate achieved
# exang: Exercise-induced angina
# oldpeak: ST depression induced by exercise
# slope: Slope of ECG curve
# ca: No. of major blood vessels
# thal: Blood disorder result
# target: Prediction

# %% [markdown]
# -Data types

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# -Data description

# %%
data.describe().T
# Out:
#           count        mean        std    min     25%    50%     75%    max
# age       302.0   54.420530   9.047970   29.0   48.00   55.5   61.00   77.0
# sex       302.0    0.682119   0.466426    0.0    0.00    1.0    1.00    1.0
# cp        302.0    0.963576   1.032044    0.0    0.00    1.0    2.00    3.0
# trestbps  302.0  131.602649  17.563394   94.0  120.00  130.0  140.00  200.0
# chol      302.0  246.500000  51.753489  126.0  211.00  240.5  274.75  564.0
# fbs       302.0    0.149007   0.356686    0.0    0.00    0.0    0.00    1.0
# restecg   302.0    0.526490   0.526027    0.0    0.00    1.0    1.00    2.0
# thalach   302.0  149.569536  22.903527   71.0  133.25  152.5  166.00  202.0
# exang     302.0    0.327815   0.470196    0.0    0.00    0.0    1.00    1.0
# oldpeak   302.0    1.043046   1.161452    0.0    0.00    0.8    1.60    6.2
# slope     302.0    1.397351   0.616274    0.0    1.00    1.0    2.00    2.0
# ...

# %% [markdown]
# -Checking missing values in the data

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# No missing values

# %% [markdown]
# -Checking duplicate values in the data

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# -Removing duplicate values

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# -Distribution of target data

# %%
sns.countplot(x='target',data=data)
plt.title('Heart Disease Distribution')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# -Age Distribution

# %%
plt.hist(data['age'],bins=10)
plt.xlabel('Age')
plt.ylabel('No. of Patients')
plt.show()

# %% [markdown]
# -Correlation Heatmap

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.show()
